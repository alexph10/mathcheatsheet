# %% [markdown]
# # Title — companion notebook
#
# Runnable companion for [`unique-slug-here.md`](./unique-slug-here.md).
#
# **Purpose:** worked numerical examples, plots, sanity checks.
#
# **Not for:** restating the math — that lives in the `.md`. Code here should illustrate, not duplicate.

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(0)

# %% [markdown]
# ## 1. Minimal example
#
# Smallest case that shows the concept working.

# %%
# code here

# %% [markdown]
# ## 2. Visualization
#
# Plot if it helps geometric intuition.

# %%
# plotting code

# %% [markdown]
# ## 3. Edge case / pitfall demo
#
# Show one of the pitfalls listed in the markdown sheet, numerically.
